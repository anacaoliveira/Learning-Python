# %%
# !pip install pandas
# !pip install tweepy
# !pip install vaderSentiment
# Out:
# ...
#     100% |████████████████████████████████| 133kB 6.0MB/s
# ...

# %%
import tweepy
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Out:
# /usr/local/lib/python3.6/dist-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
#My Twitter API Authentication Variables
consumer_key = 'kol7EmDD1GgjqcsRaP6XlVtKD'
consumer_secret = 'NM6ynsk8Fw1XHEh9qVpiSa452TfcS6aT03HACctolG9HSjI5Lc'
access_token = '883018904515338247-PJ0kNuLpN6B3BpJD1SXPMDc7Md4xBHe'
access_token_secret = 'CyER7gcO8Vt0LNBtqOGU45JEii6eQrXeaoKDZKHd3U7Zf'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

tweets = api.search('Donald Trump', count=200)


data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

display(data.head(10))


print(tweets[0].created_at)
# Out:
#                                               Tweets
# 0  RT @MichaelDelauzon: THROWBACK THURSDAYS\nDona...
# 1  RT @krassenstein: Sarah Sanders:  “I think tha...
# 2  I just be sittin here wondering how donald tru...
# 3  RT @WhiteHouse: "Women and children are the bi...
# 4  RT @MichaelDelauzon: THROWBACK THURSDAYS\nDona...
# 5  Is that the same God who wanted Hitler chancel...
# 6  RT @DavidCornDC: Sarah Sanders on CBN: "[God] ...
# 7  RT @Frigg4Jesus: So Democrats think if they sa...
# 8  RT @ActualidadRT: "Peor aún que Afganistán": D...
# 9  RT @AlanMaciasatlaw: As of 9 am today I've com...
# 2019-01-31 13:47:10

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
sid = SentimentIntensityAnalyzer()


listy = []

for index, row in data.iterrows():
  ss = sid.polarity_scores(row["Tweets"])
  listy.append(ss)
  
se = pd.Series(listy)
data['polarity'] = se.values

display(data.head(100))
# Out:
#                                                Tweets  \
# 0   RT @MichaelDelauzon: THROWBACK THURSDAYS\nDona...
# 1   RT @krassenstein: Sarah Sanders:  “I think tha...
# 2   I just be sittin here wondering how donald tru...
# 3   RT @WhiteHouse: "Women and children are the bi...
# 4   RT @MichaelDelauzon: THROWBACK THURSDAYS\nDona...
# 5   Is that the same God who wanted Hitler chancel...
# 6   RT @DavidCornDC: Sarah Sanders on CBN: "[God] ...
# 7   RT @Frigg4Jesus: So Democrats think if they sa...
# 8   RT @ActualidadRT: "Peor aún que Afganistán": D...
# 9   RT @AlanMaciasatlaw: As of 9 am today I've com...
# 10  RT @KwekuKorea: What is coming up is bigger th...
# 11  RT @BoycottUtah: It is Thursday, January 31, 2...
# 12        @realDonaldTrump Thank GOD for Donald Trump
# 13  @realDonaldTrump @trumps_feed @LouDobbs @foxan...
# 14  RT @_ju1_: Para saber en 2 minutos de lo que v...
# 15  RT @KatiePhang: God 'wanted Donald Trump to be...
# ...
